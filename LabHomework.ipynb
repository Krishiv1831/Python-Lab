# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishiv1831/Python-Lab/blob/main/LabHomework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a program for simple calculator

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Sum =", a + b)
print("Difference =", a - b)
print("Product =", a * b)
print("Quotient =", a / b)

# %%
#Take marks from 5 students & find sum & average

m1 = int(input("Enter marks of student 1: "))
m2 = int(input("Enter marks of student 2: "))
m3 = int(input("Enter marks of student 3: "))
m4 = int(input("Enter marks of student 4: "))
m5 = int(input("Enter marks of student 5: "))

total = m1 + m2 + m3 + m4 + m5
average = total / 5

print("Sum =", total)
print("Average =", average)

# %%
#Find area of circle

r = float(input("Enter radius: "))

area = 3.14 * r * r

print("Area of circle =", area)

# %%
#Find area & perimeter of rectangle

l = float(input("Enter length: "))
b = float(input("Enter breadth: "))

area = l * b
perimeter = 2 * (l + b)

print("Area =", area)
print("Perimeter =", perimeter)
